# %%
import pandas as pd

male = pd.read_csv(
    "nhanes_adult_male_bmx_2020.csv",
    comment="#"
)

female = pd.read_csv(
    "nhanes_adult_female_bmx_2020.csv",
    comment="#"
)

print("Male Dataset Shape :", male.shape)
print("Female Dataset Shape :", female.shape)

male.head()
# Out:
# Male Dataset Shape : (4081, 7)
# Female Dataset Shape : (4221, 7)
#    BMXWT  BMXHT  BMXARML  BMXLEG  BMXARMC  BMXHIP  BMXWAIST
# 0   98.8  182.3     42.0    40.1     38.2   108.2     120.4
# 1   74.3  184.2     41.1    41.0     30.2    94.5      86.8
# 2  103.7  185.3     47.0    44.0     32.0   107.8     109.6
# 3   86.0  167.8     39.5    38.4     29.0   106.4     108.3
# 4   99.4  181.6     40.4    39.9     36.0   120.2     107.0

# %% [markdown]
# ## Step 1: Loading the Dataset
#
# ### Objective
# In this step, the male and female NHANES datasets are loaded into Python using the Pandas library. The datasets are checked to ensure they are loaded correctly before further analysis.

# %%
# Display first 5 rows of each dataset

print("Male Dataset")
display(male.head())

print("\nFemale Dataset")
display(female.head())
# Out:
# Male Dataset
#    BMXWT  BMXHT  BMXARML  BMXLEG  BMXARMC  BMXHIP  BMXWAIST
# 0   98.8  182.3     42.0    40.1     38.2   108.2     120.4
# 1   74.3  184.2     41.1    41.0     30.2    94.5      86.8
# 2  103.7  185.3     47.0    44.0     32.0   107.8     109.6
# 3   86.0  167.8     39.5    38.4     29.0   106.4     108.3
# 4   99.4  181.6     40.4    39.9     36.0   120.2     107.0
# Female Dataset
#    BMXWT  BMXHT  BMXARML  BMXLEG  BMXARMC  BMXHIP  BMXWAIST
# 0   97.1  160.2     34.7    40.8     35.8   126.1     117.9
# 1   91.1  152.7     33.5    33.0     38.5   125.5     103.1
# 2   73.0  161.2     37.4    38.0     31.8   106.2      92.0
# 3   61.7  157.4     38.0    34.7     29.0   101.0      90.5
# 4   55.4  154.6     34.6    34.0     28.3    92.5      73.2

# %%
# Display dataset information

print("Male Dataset Information")
male.info()

print("\nFemale Dataset Information")
female.info()
# Out:
# Male Dataset Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4081 entries, 0 to 4080
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BMXWT     4081 non-null   float64
#  1   BMXHT     4081 non-null   float64
#  2   BMXARML   4081 non-null   float64
#  3   BMXLEG    4081 non-null   float64
#  4   BMXARMC   4081 non-null   float64
#  5   BMXHIP    4081 non-null   float64
#  6   BMXWAIST  4081 non-null   float64
# dtypes: float64(7)
# memory usage: 223.3 KB
#
# Female Dataset Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4221 entries, 0 to 4220
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BMXWT     4221 non-null   float64
#  1   BMXHT     4221 non-null   float64
#  2   BMXARML   4221 non-null   float64
#  3   BMXLEG    4221 non-null   float64
#  4   BMXARMC   4221 non-null   float64
# ...

# %%
# Display statistical summary

print("Male Dataset Summary")
display(male.describe())

print("\nFemale Dataset Summary")
display(female.describe())
# Out:
# Male Dataset Summary
#              BMXWT        BMXHT      BMXARML       BMXLEG      BMXARMC  \
# count  4081.000000  4081.000000  4081.000000  4081.000000  4081.000000
# mean     88.364543   173.827028    39.215045    41.341240    34.334183
# std      21.421561     7.662410     2.435982     3.214881     4.785677
# min      36.800000   144.600000    29.600000    27.500000    19.000000
# 25%      73.300000   168.600000    37.500000    39.200000    31.000000
# 50%      85.000000   173.800000    39.100000    41.200000    34.000000
# 75%      99.800000   178.900000    40.900000    43.500000    37.300000
# max     204.600000   199.600000    49.900000    53.000000    53.600000
#
#             BMXHIP     BMXWAIST
# count  4081.000000  4081.000000
# mean    104.495099   101.789414
# std      12.211841    16.540779
# min      77.000000    62.300000
# 25%      96.000000    90.100000
# 50%     102.700000   100.600000
# 75%     110.600000   111.900000
# max     174.900000   170.800000
# ...

# %% [markdown]
# ### Interpretation
#
# - Both datasets were loaded successfully.
# - Each dataset contains body measurement information of adult participants.
# - The statistical summary provides information such as mean, standard deviation, minimum and maximum values.
# - These datasets will be used for further analysis and visualization in the next steps.

# %% [markdown]
# ## Step 2: Histogram of Male and Female Weights
#
# ### Objective
# The objective of this step is to compare the weight distribution of male and female participants using histograms.

# %%
print(male.columns)
print(female.columns)
# Out:
# Index(['BMXWT', 'BMXHT', 'BMXARML', 'BMXLEG', 'BMXARMC', 'BMXHIP', 'BMXWAIST'], dtype='object')
# Index(['BMXWT', 'BMXHT', 'BMXARML', 'BMXLEG', 'BMXARMC', 'BMXHIP', 'BMXWAIST'], dtype='object')

# %% [markdown]
# ## Step 3: Histogram of Male and Female Weights
#
# ### Objective
# The objective of this step is to compare the weight distribution of male and female participants using histograms.

# %%
# Import matplotlib
import matplotlib.pyplot as plt

# Extract weight column
male_weights = male["BMXWT"]
female_weights = female["BMXWT"]

# Find common x-axis limits
xmin = min(male_weights.min(), female_weights.min())
xmax = max(male_weights.max(), female_weights.max())

# Create figure
plt.figure(figsize=(10,8))

# Female Histogram
plt.subplot(2,1,1)
plt.hist(female_weights, bins=20, color="pink", edgecolor="black")
plt.title("Female Weight Distribution")
plt.xlabel("Weight (kg)")
plt.ylabel("Frequency")
plt.xlim(xmin, xmax)

# Male Histogram
plt.subplot(2,1,2)
plt.hist(male_weights, bins=20, color="skyblue", edgecolor="black")
plt.title("Male Weight Distribution")
plt.xlabel("Weight (kg)")
plt.ylabel("Frequency")
plt.xlim(xmin, xmax)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation
#
# - Two histograms were created to compare the weight distribution of male and female participants.
# - The x-axis limits were kept the same to make comparison easier.
# - Most participants are concentrated around the average weight range.
# - The histogram helps identify the spread and distribution of weights in both groups.

# %% [markdown]
# ## Step 4: Box Plot of Male and Female Weights
#
# ### Objective
# The objective of this step is to compare the weight distribution of male and female participants using a box plot.

# %%
# Box Plot of Male and Female Weights

plt.figure(figsize=(8,6))

plt.boxplot([female["BMXWT"], male["BMXWT"]],
            labels=["Female", "Male"],
            patch_artist=True)

plt.title("Comparison of Male and Female Weights")
plt.ylabel("Weight (kg)")

plt.grid(True)

plt.show()
# Out:
# /tmp/ipykernel_722/3483547679.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([female["BMXWT"], male["BMXWT"]],

# %% [markdown]
# ### Interpretation
#
# - The box plot compares the weight distribution of male and female participants.
# - The median weight of males is generally higher than that of females.
# - The spread of male weights appears larger than female weights.
# - A few outliers are present in both groups, representing participants with unusually high or low body weights.
# - The box plot provides a clear comparison of the central tendency and variability between the two groups.

# %% [markdown]
# ## Step 5: Basic Numerical Aggregates of Male and Female Weights
#
# ### Objective
# The objective of this step is to calculate and compare the statistical measures of male and female weights, including measures of location, dispersion, and shape.

# %%
# Import required library
import pandas as pd

# Calculate statistical measures

male_stats = {
    "Mean": male["BMXWT"].mean(),
    "Median": male["BMXWT"].median(),
    "Minimum": male["BMXWT"].min(),
    "Maximum": male["BMXWT"].max(),
    "Range": male["BMXWT"].max() - male["BMXWT"].min(),
    "Variance": male["BMXWT"].var(),
    "Standard Deviation": male["BMXWT"].std(),
    "Skewness": male["BMXWT"].skew(),
    "Kurtosis": male["BMXWT"].kurt()
}

female_stats = {
    "Mean": female["BMXWT"].mean(),
    "Median": female["BMXWT"].median(),
    "Minimum": female["BMXWT"].min(),
    "Maximum": female["BMXWT"].max(),
    "Range": female["BMXWT"].max() - female["BMXWT"].min(),
    "Variance": female["BMXWT"].var(),
    "Standard Deviation": female["BMXWT"].std(),
    "Skewness": female["BMXWT"].skew(),
    "Kurtosis": female["BMXWT"].kurt()
}

# Create comparison table
comparison = pd.DataFrame({
    "Male": male_stats,
    "Female": female_stats
})

comparison
# Out:
#                           Male      Female
# Mean                 88.364543   77.403791
# Median               85.000000   73.600000
# Minimum              36.800000   32.600000
# Maximum             204.600000  180.900000
# Range               167.800000  148.300000
# Variance            458.883294  464.189635
# Standard Deviation   21.421561   21.545061
# Skewness              0.984643    1.033728
# Kurtosis              1.477568    1.404052

# %% [markdown]
# ### Interpretation
#
# - The mean and median values indicate the average weight of male and female participants.
# - The standard deviation and variance show how much the weights vary within each group.
# - The range represents the difference between the maximum and minimum weights.
# - The skewness value indicates whether the distribution is left-skewed or right-skewed.
# - The kurtosis value describes the shape of the distribution and whether it contains extreme values (outliers).
# - Overall, these statistical measures help compare the weight distributions of male and female participants.

# %% [markdown]
# ## Step 6: Calculate Body Mass Index (BMI)
#
# ### Objective
# The objective of this step is to calculate the Body Mass Index (BMI) for each female participant and add it as a new column to the female dataset.

# %%
# Calculate BMI
# Formula: BMI = Weight (kg) / (Height in meter)^2

female["BMI"] = female["BMXWT"] / ((female["BMXHT"] / 100) ** 2)

# Display first 5 rows
female.head()
# Out:
#    BMXWT  BMXHT  BMXARML  BMXLEG  BMXARMC  BMXHIP  BMXWAIST        BMI
# 0   97.1  160.2     34.7    40.8     35.8   126.1     117.9  37.835041
# 1   91.1  152.7     33.5    33.0     38.5   125.5     103.1  39.069720
# 2   73.0  161.2     37.4    38.0     31.8   106.2      92.0  28.092655
# 3   61.7  157.4     38.0    34.7     29.0   101.0      90.5  24.904378
# 4   55.4  154.6     34.6    34.0     28.3    92.5      73.2  23.178791

# %%
# Display only Height, Weight and BMI

female[["BMXWT", "BMXHT", "BMI"]].head(10)
# Out:
#    BMXWT  BMXHT        BMI
# 0   97.1  160.2  37.835041
# 1   91.1  152.7  39.069720
# 2   73.0  161.2  28.092655
# 3   61.7  157.4  24.904378
# 4   55.4  154.6  23.178791
# 5   62.0  144.7  29.611106
# 6   66.2  166.5  23.879736
# 7   75.9  154.5  31.796902
# 8   77.2  159.2  30.460089
# 9   91.6  174.5  30.081855

# %% [markdown]
# ### Interpretation
#
# - A new column named **BMI** was successfully added to the female dataset.
# - BMI was calculated using the standard formula:
#
#   **BMI = Weight (kg) / Height² (m²)**
#
# - BMI helps determine whether a person's body weight is appropriate for their height.
# - This new column will be used in the upcoming analysis and visualizations.

# %% [markdown]
# ## Step 7: Standardize the Female Dataset (Z-Score)
#
# ### Objective
# The objective of this step is to standardize all numerical columns in the female dataset using the Z-score method. This ensures that all variables are on the same scale, making them suitable for comparison and further statistical analysis.

# %%
# Import StandardScaler
from sklearn.preprocessing import StandardScaler

# Create StandardScaler object
scaler = StandardScaler()

# Standardize all columns
zfemale = scaler.fit_transform(female)

# Convert back to DataFrame
zfemale = pd.DataFrame(zfemale, columns=female.columns)

# Display first 5 rows
zfemale.head()
# Out:
#       BMXWT     BMXHT   BMXARML    BMXLEG   BMXARMC    BMXHIP  BMXWAIST  \
# 0  0.914295  0.008950 -0.567395  1.132988  0.550845  1.083162  1.115785
# 1  0.635776 -1.053068 -1.078931 -1.293492  1.032218  1.044755  0.265089
# 2 -0.204423  0.150553  0.583563  0.261944 -0.162299 -0.190647 -0.372933
# 3 -0.728968 -0.387537  0.839332 -0.764643 -0.661500 -0.523501 -0.459152
# 4 -1.021413 -0.784024 -0.610023 -0.982404 -0.786301 -1.067590 -1.453546
#
#         BMI
# 0  0.996968
# 1  1.156175
# 2 -0.259275
# 3 -0.670391
# 4 -0.892899

# %%
# Check mean and standard deviation

print("Mean of standardized columns")
print(zfemale.mean())

print("\nStandard Deviation of standardized columns")
print(zfemale.std())
# Out:
# Mean of standardized columns
# BMXWT      -2.087356e-16
# BMXHT       1.892087e-15
# BMXARML     7.659250e-16
# BMXLEG      5.639228e-16
# BMXARMC     1.010011e-17
# BMXHIP      5.555060e-16
# BMXWAIST   -8.585093e-16
# BMI         1.380348e-16
# dtype: float64
#
# Standard Deviation of standardized columns
# BMXWT       1.000118
# BMXHT       1.000118
# BMXARML     1.000118
# BMXLEG      1.000118
# BMXARMC     1.000118
# BMXHIP      1.000118
# BMXWAIST    1.000118
# BMI         1.000118
# dtype: float64

# %% [markdown]
# ### Interpretation
#
# - All numerical columns in the female dataset were standardized using the Z-score method.
# - After standardization, the mean of each column is approximately **0**.
# - The standard deviation of each column is approximately **1**.
# - Standardization removes the effect of different measurement scales and prepares the data for correlation analysis and visualization.

# %% [markdown]
# ## Step 8: Pairplot and Correlation Analysis
#
# ### Objective
# The objective of this step is to visualize the relationship between Height, Weight, Waist Circumference, Hip Circumference and BMI using a pairplot. Pearson and Spearman correlation coefficients are also calculated to measure the relationship between these variables.

# %%
# Import required libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Select required columns
selected = zfemale[["BMXHT", "BMXWT", "BMXWAIST", "BMXHIP", "BMI"]]

# Pairplot
sns.pairplot(selected)

plt.show()

# %%
# Pearson Correlation

pearson_corr = selected.corr(method="pearson")

print("Pearson Correlation Matrix")
display(pearson_corr)
# Out:
# Pearson Correlation Matrix
#              BMXHT     BMXWT  BMXWAIST    BMXHIP       BMI
# BMXHT     1.000000  0.345496  0.126547  0.202895  0.033077
# BMXWT     0.345496  1.000000  0.904550  0.946553  0.945900
# BMXWAIST  0.126547  0.904550  1.000000  0.897407  0.921198
# BMXHIP    0.202895  0.946553  0.897407  1.000000  0.944199
# BMI       0.033077  0.945900  0.921198  0.944199  1.000000

# %%
# Spearman Correlation

spearman_corr = selected.corr(method="spearman")

print("Spearman Correlation Matrix")
display(spearman_corr)
# Out:
# Spearman Correlation Matrix
#              BMXHT     BMXWT  BMXWAIST    BMXHIP       BMI
# BMXHT     1.000000  0.338860  0.108587  0.205405  0.019897
# BMXWT     0.338860  1.000000  0.900169  0.946634  0.937999
# BMXWAIST  0.108587  0.900169  1.000000  0.888037  0.923114
# BMXHIP    0.205405  0.946634  0.888037  1.000000  0.934196
# BMI       0.019897  0.937999  0.923114  0.934196  1.000000

# %% [markdown]
# ### Interpretation
#
# - The pairplot shows the relationship between height, weight, waist circumference, hip circumference and BMI.
# - Pearson correlation measures the strength of the linear relationship between variables.
# - Spearman correlation measures the monotonic relationship between variables.
# - Weight, Waist Circumference and BMI generally show a strong positive correlation.
# - Height usually has a weaker correlation with BMI compared to weight and waist circumference.
# - These correlations help identify which body measurements are most closely related.

# %% [markdown]
# ## Step 9: Calculate Waist-to-Height Ratio and Waist-to-Hip Ratio
#
# ### Objective
# The objective of this step is to calculate the Waist-to-Height Ratio (WHtR) and Waist-to-Hip Ratio (WHR) for both male and female participants by adding two new columns to each dataset.

# %%
# Calculate Waist-to-Height Ratio (WHtR)
male["WHtR"] = male["BMXWAIST"] / male["BMXHT"]
female["WHtR"] = female["BMXWAIST"] / female["BMXHT"]

# Calculate Waist-to-Hip Ratio (WHR)
male["WHR"] = male["BMXWAIST"] / male["BMXHIP"]
female["WHR"] = female["BMXWAIST"] / female["BMXHIP"]

# Display first 5 rows
print("Male Dataset")
display(male.head())

print("Female Dataset")
display(female.head())
# Out:
# Male Dataset
#    BMXWT  BMXHT  BMXARML  BMXLEG  BMXARMC  BMXHIP  BMXWAIST      WHtR  \
# 0   98.8  182.3     42.0    40.1     38.2   108.2     120.4  0.660450
# 1   74.3  184.2     41.1    41.0     30.2    94.5      86.8  0.471227
# 2  103.7  185.3     47.0    44.0     32.0   107.8     109.6  0.591473
# 3   86.0  167.8     39.5    38.4     29.0   106.4     108.3  0.645411
# 4   99.4  181.6     40.4    39.9     36.0   120.2     107.0  0.589207
#
#         WHR
# 0  1.112754
# 1  0.918519
# 2  1.016698
# 3  1.017857
# 4  0.890183
# Female Dataset
#    BMXWT  BMXHT  BMXARML  BMXLEG  BMXARMC  BMXHIP  BMXWAIST        BMI  \
# 0   97.1  160.2     34.7    40.8     35.8   126.1     117.9  37.835041
# 1   91.1  152.7     33.5    33.0     38.5   125.5     103.1  39.069720
# 2   73.0  161.2     37.4    38.0     31.8   106.2      92.0  28.092655
# 3   61.7  157.4     38.0    34.7     29.0   101.0      90.5  24.904378
# 4   55.4  154.6     34.6    34.0     28.3    92.5      73.2  23.178791
#
# ...

# %%
# Display only the newly created columns

print("Male Ratios")
display(male[["WHtR", "WHR"]].head(10))

print("Female Ratios")
display(female[["WHtR", "WHR"]].head(10))
# Out:
# Male Ratios
#        WHtR       WHR
# 0  0.660450  1.112754
# 1  0.471227  0.918519
# 2  0.591473  1.016698
# 3  0.645411  1.017857
# 4  0.589207  0.890183
# 5  0.715077  1.054446
# 6  0.421846  0.819512
# 7  0.471698  0.928009
# 8  0.523466  0.931478
# 9  0.550406  0.985477
# Female Ratios
#        WHtR       WHR
# 0  0.735955  0.934972
# 1  0.675180  0.821514
# 2  0.570720  0.866290
# 3  0.574968  0.896040
# 4  0.473480  0.791351
# 5  0.586040  0.794752
# 6  0.574775  0.993769
# 7  0.638835  0.916435
# 8  0.612437  0.955882
# 9  0.574785  0.826876

# %% [markdown]
# ### Interpretation
#
# - Two new columns were successfully added to both the male and female datasets.
# - Waist-to-Height Ratio (WHtR) compares waist circumference with height.
# - Waist-to-Hip Ratio (WHR) compares waist circumference with hip circumference.
# - These ratios are useful indicators of body fat distribution and health risk.
# - These new variables will be used in the next step for comparison using box plots.

# %% [markdown]
# ## Step 10: Box Plot of WHtR and WHR
#
# ### Objective
# The objective of this step is to compare the Waist-to-Height Ratio (WHtR) and Waist-to-Hip Ratio (WHR) of male and female participants using box plots.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

plt.boxplot(
    [
        female["WHtR"],
        male["WHtR"],
        female["WHR"],
        male["WHR"]
    ],
    tick_labels=[
        "Female\nWHtR",
        "Male\nWHtR",
        "Female\nWHR",
        "Male\nWHR"
    ],
    patch_artist=True
)

plt.title("Comparison of Waist-to-Height Ratio and Waist-to-Hip Ratio")
plt.ylabel("Ratio")
plt.grid(True)

plt.show()

# %% [markdown]
# ### Interpretation
#
# - The box plot compares the Waist-to-Height Ratio (WHtR) and Waist-to-Hip Ratio (WHR) of male and female participants.
# - The median values help compare the central tendency of each ratio.
# - The spread of the box indicates the variability in each group.
# - Outliers represent participants with unusually high or low ratio values.
# - These ratios provide better insight into body fat distribution than body weight alone.

# %% [markdown]
# ## Step 11: Advantages and Disadvantages of BMI, WHtR and WHR
#
# ### Objective
# The objective of this step is to discuss the advantages and disadvantages of Body Mass Index (BMI), Waist-to-Height Ratio (WHtR), and Waist-to-Hip Ratio (WHR).
#
# ### Body Mass Index (BMI)
#
# #### Advantages
# - BMI is easy to calculate.
# - It requires only height and weight.
# - It is widely used for health screening.
# - It helps classify individuals as underweight, normal, overweight, or obese.
#
# #### Disadvantages
# - BMI cannot distinguish between muscle mass and body fat.
# - It does not show fat distribution in the body.
# - It may incorrectly classify athletes as overweight.
# - It is not equally accurate for all age groups.
#
# ---
#
# ### Waist-to-Height Ratio (WHtR)
#
# #### Advantages
# - It is a good indicator of abdominal fat.
# - It helps predict the risk of heart disease and diabetes.
# - It is simple to calculate.
# - It is more informative than BMI in many situations.
#
# #### Disadvantages
# - Accurate waist measurement is required.
# - It does not measure overall body fat.
# - It may vary depending on measurement technique.
#
# ---
#
# ### Waist-to-Hip Ratio (WHR)
#
# #### Advantages
# - It measures body fat distribution.
# - It helps identify obesity-related health risks.
# - It is useful in predicting cardiovascular diseases.
#
# #### Disadvantages
# - Accurate waist and hip measurements are necessary.
# - It does not indicate total body fat.
# - Small measurement errors can affect the result.
#
# ### Conclusion
#
# BMI, WHtR and WHR are useful health indicators. However, each method has its own strengths and limitations. Using all three together provides a better understanding of a person's overall health.

# %% [markdown]
# ## Step 12: Display the Standardized Body Measurements of Participants with Lowest and Highest BMI
#
# ### Objective
#
# The objective of this step is to identify the 5 participants with the lowest BMI and the 5 participants with the highest BMI. Their standardized body measurements are displayed and interpreted.

# %%
# Find indices of the 5 lowest BMI values
lowest_bmi = female["BMI"].nsmallest(5).index

# Find indices of the 5 highest BMI values
highest_bmi = female["BMI"].nlargest(5).index

print("Standardized Body Measurements of 5 Participants with Lowest BMI")
display(zfemale.loc[lowest_bmi])

print("\nStandardized Body Measurements of 5 Participants with Highest BMI")
display(zfemale.loc[highest_bmi])
# Out:
# Standardized Body Measurements of 5 Participants with Lowest BMI
#          BMXWT     BMXHT   BMXARML    BMXLEG   BMXARMC    BMXHIP  BMXWAIST  \
# 262  -2.079785 -1.222991 -1.547840 -1.169057 -2.194761 -2.040550 -1.942121
# 3478 -1.880180 -0.189293 -1.718352  0.386379 -2.444362 -1.854919 -2.057080
# 2126 -1.536673  1.807302  0.626191  0.573031 -2.266076 -1.675690 -1.706456
# 2753 -1.843044 -0.260094 -0.226370  0.510814 -2.301733 -2.251784 -1.855902
# 1209 -1.610945  0.886886 -0.098486  0.479705 -2.212590 -1.829315 -1.712204
#
#            BMI
# 262  -2.050240
# 3478 -1.994880
# 2126 -1.970884
# 2753 -1.941776
# 1209 -1.893196
# Standardized Body Measurements of 5 Participants with Highest BMI
#          BMXWT     BMXHT   BMXARML    BMXLEG   BMXARMC    BMXHIP  BMXWAIST  \
# 1096  4.363290 -0.033530 -0.055858 -0.173578  2.779422  4.315691  4.570299
# 1104  4.804279  0.886886  2.118174  1.817380  3.777825  4.021242  4.081723
# ...

# %% [markdown]
# ### Interpretation
#
# - The standardized body measurements of the 5 participants with the lowest BMI and the 5 participants with the highest BMI were displayed.
# - Participants with the lowest BMI generally have lower standardized values for weight, waist circumference, and hip circumference.
# - Participants with the highest BMI generally have higher standardized values for weight, waist circumference, and hip circumference.
# - Height does not vary as much as weight and body circumference measurements.
# - This comparison shows that BMI is strongly influenced by body weight and body size measurements.
